# %% [markdown]
# # IK Solvers Tests

# %%
import rospy
import moveit_commander
import moveit_msgs.msg
import moveit_msgs.srv
import sys
import csv
import tf_conversions
import geometry_msgs.msg
import golem_right_arm_kinematics as grk
import golem_left_arm_kinematics as glk
import timeit
import math

# %% [markdown]
# ## Define some functions to work with ROS Services

# %%
# Transform a pose tuple into MoveIt! IK request msg
def ik_req_from_pose((x, y, z, yaw, pitch, roll), solver='custom'):
    # srv request definition
    ik_req = moveit_msgs.srv.GetPositionIKRequest()
    
    if solver == 'kdl':
        quaternion = tf_conversions.transformations.quaternion_from_euler(yaw, pitch, roll)
    elif solver == 'custom':
        quaternion = tf_conversions.transformations.quaternion_from_euler(pitch, yaw, roll, axes='szyx')

    # Desired end effector position
    desired_pose = geometry_msgs.msg.PoseStamped()
    desired_pose.pose.position.x = x
    desired_pose.pose.position.y = y
    desired_pose.pose.position.z = z
    desired_pose.pose.orientation.x = quaternion[0]
    desired_pose.pose.orientation.y = quaternion[1]
    desired_pose.pose.orientation.z = quaternion[2]
    desired_pose.pose.orientation.w = quaternion[3]

    ik_req.ik_request.group_name = 'right_arm_kdl'
    ik_req.ik_request.robot_state = robot.get_current_state()
    # ik_req.ik_request.constraints
    ik_req.ik_request.avoid_collisions = True
    ik_req.ik_request.ik_link_name = 'r_eef'
    ik_req.ik_request.pose_stamped = desired_pose
    ik_req.ik_request.timeout.secs = 5
    ik_req.ik_request.attempts = 0
    
    return ik_req

# Transform MoveIt! IK response msg into a list of joints
def joint_list_from_ik_resp(ikresp, joint_names):
    joint_dic = {}
    joint_list = []
    joints = ikresp.solution.joint_state.name
    angles = ikresp.solution.joint_state.position
    
    for i in range(len(joints)):
        joint_dic[joints[i]] = angles[i]
        
    for j in range(len(joint_names)):
        if joint_names[j] in joint_dic.keys():
            joint_list.append(round(joint_dic[joint_names[j]],6))
        
    return joint_list


# Tranform a list of joints into a MoveIt! FK request msg
def fk_req_from_joint_list(joints):
    complete_joints = (0.0, joints[0], 0.0, 0.0, 
                      joints[1], 
                      joints[2],
                      joints[3],
                      joints[4],
                      joints[5],
                      0.0, 0.0, joints[1], joints[2], joints[3], joints[4], joints[5], 0.0, 0.0)
    
    # srv request definition
    fk_req = moveit_msgs.srv.GetPositionFKRequest()
    fk_req.fk_link_names = ['r_eef']
    fk_req.robot_state = robot.get_current_state()
    fk_req.robot_state.joint_state.position = complete_joints
    
    return fk_req

# Transform a MoveIt! FK response msg into a list with the pose
def pose_from_fk_resp(fk_resp):
    msg_pose = fk_resp.pose_stamped[0].pose
    
    rpy = tf_conversions.transformations.euler_from_quaternion((
        msg_pose.orientation.x, 
        msg_pose.orientation.y, 
        msg_pose.orientation.z,
        msg_pose.orientation.w))

    pose = (
        round(msg_pose.position.x,6), 
        round(msg_pose.position.y,6), 
        round(msg_pose.position.z,6), 
        round(rpy[0],6), 
        round(rpy[1],6), 
        round(rpy[2],6)
    )
    
    return pose

# Compute error of IK solutions
# The inputs are the desired pose and the FK of IK solution
def compute_error(desired_pose, solution):
    error = 0.0
    for k in range(len(desired_pose)):
        error += (desired_pose[k] - solution[k])/desired_pose[k]

    return abs(error)

# Transform to quaternion from roll-pitch-yaw
def rpy2quaternion(yaw, pitch, roll):
    t0 = math.cos(roll*0.5)
    t1 = math.sin(roll*0.5)
    t2 = math.cos(yaw*0.5)
    t3 = math.sin(yaw*0.5)
    t4 = math.cos(pitch*0.5)
    t5 = math.sin(pitch*0.5)
    
    q = (
        t0 * t3 * t4 - t1 * t2 * t5,
        t0 * t2 * t5 + t1 * t3 * t4,
        t1 * t2 * t4 - t0 * t3 * t5,
        t0 * t2 * t4 + t1 * t3 * t5
    )
    return q

# Transform a roll-pitch-yaw orientation to a quaternion
def quaternion2rpy(x, y, z, w):
    sp = 2*(x*z - w*y)
    roll = math.atan2(2*(-x*y + z*w), 1 - 2*(y**2 + z**2))
    pitch = math.asin(sp)
    yaw = math.atan2(2*(-x*w + y*z), 1 - 2*(z**2 + w**2))
    
    return (yaw, pitch, roll)

# %% [markdown]
# ## 1. MoveIt! Setup
# **NOTE:** Before running the next code, golem_moveit.launch must be launched!

# %%
moveit_commander.roscpp_initialize(sys.argv)

# Robot commander object -> interface the robot as a whole
robot = moveit_commander.RobotCommander()
# MoveGroup object
right_arm = moveit_commander.MoveGroupCommander("right_arm_kdl")

print "============ ROBOT COMMANDER STARTED! ============="
# Out:
# ============ ROBOT COMMANDER STARTED! =============

# %% [markdown]
# ## 2. Import test points from file

# %%
# Read file and storage poses in 'test_pose' variable as tuples
f = open('ik_test_poses/left_arm_test_poses(1000).csv', 'r')
test_poses = []
for line in f:
    pose = []
    for string in line.split(','):
        pose.append(round(float(string),6))
    pose = tuple(pose)
    test_poses.append(pose)
test_poses = tuple(test_poses)
print len(test_poses), 'poses read!'

# e = 0
# for pose in test_poses:
#     ikt = glk.inverse_kinematics(*pose)
#     if not ikt:
#         e+=1
# print e, 'poses without solution.'
# Out:
# 100 poses read!

# %%
test_poses[3]
# Out:
# (-0.196146, -0.411833, 1.313852, 0.175251, -0.851744, -2.388338)

# %% [markdown]
# ## 3. Tests
# ### 3.1 Init service clients for FK and IK

# %%
# Init service client object
rospy.wait_for_service('/golem_kinematics/left_arm/compute_fk')
rospy.wait_for_service('/golem_kinematics/left_arm/compute_ik')
print "FK and IK services were found!"

compute_custom_ik = rospy.ServiceProxy('/golem_kinematics/left_arm/compute_ik', moveit_msgs.srv.GetPositionIK)
compute_custom_ik_op = rospy.ServiceProxy('/golem_kinematics/left_arm/compute_ik_only_position', moveit_msgs.srv.GetPositionIK)
# compute_kdl_ik = rospy.ServiceProxy('/compute_ik', moveit_msgs.srv.GetPositionIK)
compute_custom_fk = rospy.ServiceProxy('/golem_kinematics/left_arm/compute_fk', moveit_msgs.srv.GetPositionFK)
# compute_kdl_fk = rospy.ServiceProxy('/compute_fk', moveit_msgs.srv.GetPositionFK)
print "Service client objects created!"
# Out:
# FK and IK services were found!
# Service client objects created!

# %%
test_pose = (1.0, 0.0, 1.3, 0.0, 0.0, 0.0)

print '-------------------------------'
print '---------- TEST ', 1, ' ----------'
print '-------------------------------'

# Transform pose tuple to IK MoveIt! msg
cs_ik_req = ik_req_from_pose(test_pose,'custom')

# IK computation
cs_ik = compute_custom_ik_op(cs_ik_req)

# Transform IK response into a joint list
print '### Inverse Kinematics ###'
cs_sol = joint_list_from_ik_resp(cs_ik, ('m0', 'm20', 'm21', 'm22', 'm23', 'm24'))
print 'Custom Solver:  ', cs_sol

# Transform joint list to FK request and FK computation
print '\n### Forward Kinematics ###'
print 'Pose:           ', test_pose
if cs_ik.solution.joint_state.position:
    cs_fk_req = fk_req_from_joint_list(cs_sol)
    cs_fk_resp = compute_custom_fk(cs_fk_req)
    cs_fk = pose_from_fk_resp(cs_fk_resp)
    print 'Custom Solver:  ', cs_fk
# Out:
# -------------------------------
# ---------- TEST  1  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.837832, -1.12992, 1.967752, 0.625803, -0.065803, 0.0]
#
# ### Forward Kinematics ###
# Pose:            (1.0, 0.0, 1.3, 0.0, 0.0, 0.0)
# Custom Solver:   (1.0, -0.0, 1.3, 0.0, -0.56, 0.0)

# %%
# Make an experiment for each given pose.
csvfile = open('test_results_ik001.csv', 'wb')
writer = csv.writer(csvfile, delimiter=',', quoting=csv.QUOTE_NONE)
for pose in range(len(test_poses)):
    print '-------------------------------'
    print '---------- TEST ', pose+1, ' ----------'
    print '-------------------------------'
    
    # Transform pose tuple to IK MoveIt! msg
    cs_ik_req = ik_req_from_pose(test_poses[pose],'custom')
    # kdl_ik_req = ik_req_from_pose(test_poses[pose],'kdl')

    # IK computation
    t0 = timeit.default_timer() 
    cs_ik = compute_custom_ik(cs_ik_req)
    t1 = timeit.default_timer() 
    
    # t2 = timeit.default_timer() 
    # kdl_ik = compute_kdl_ik(kdl_ik_req)
    # t3 = timeit.default_timer()
    
    cs_time = t1 - t0
    # kdl_time = t3 - t2
    
    # Transform IK response into a joint list
    print '### Inverse Kinematics ###'
    cs_sol = joint_list_from_ik_resp(cs_ik, ('m0', 'm20', 'm21', 'm22', 'm23', 'm24'))
    # kdl_sol = joint_list_from_ik_resp(kdl_ik, ('m0', 'm10', 'm11', 'm12', 'm13', 'm14'))
    print 'Custom Solver:  ', cs_sol
    # print 'KDL Solver:     ', kdl_sol
    
    # Transform joint list to FK request and FK computation
    print '\n### Forward Kinematics ###'
    print 'Pose:           ', test_poses[pose]
    if cs_ik.solution.joint_state.position:
        cs_fk_req = fk_req_from_joint_list(cs_sol)
        cs_fk_resp = compute_custom_fk(cs_fk_req)
        cs_fk = pose_from_fk_resp(cs_fk_resp)
        print 'Custom Solver:  ', cs_fk

    # if kdl_ik.solution.joint_state.position:
    #     kdl_fk_req = fk_req_from_joint_list(kdl_sol)
    #     kdl_fk_resp = compute_custom_fk(kdl_fk_req)
    #     kdl_fk = pose_from_fk_resp(kdl_fk_resp)
        # print 'KDL Solver:     ', kdl_fk
       
    # Error computation
    print '\n### Errors ###'
    
    cs_error = []
    for i in range(3):
        if cs_ik.solution.joint_state.position:
            cs_error.append(abs(cs_fk[i] - test_poses[pose][i])/test_poses[pose][i])
        else:
            cs_error.append('no')
    print 'Custom Solver:  ', cs_error
        
    # kdl_error = []
    # for j in range(6):
    #     if kdl_ik.solution.joint_state.position:
    #         kdl_error.append(abs(kdl_fk[j] - test_poses[pose][j])/test_poses[pose][i])
    #     else:
    #        kdl_error.append(-1)
    # print 'KDL Solver:     ', kdl_error
        
    data = cs_error
    data.append(cs_time)
    # data += kdl_error
    # data.append(kdl_time)
    writer.writerow(data)
        
    print '\n'
    
csvfile.close()
# Out:
# -------------------------------
# ---------- TEST  1  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.750945, 1.449907, -1.132452, 0.278868, -1.240424, -1.328203]
#
# ### Forward Kinematics ###
# Pose:            (0.064694, 0.251447, 0.712646, -1.328203, 0.961556, 1.0684)
# Custom Solver:   (0.064694, 0.251447, 0.712646, -1.328203, 0.961556, 1.0684)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  2  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.436943, -0.398842, 1.931098, 1.471565, -1.594355, 0.749859]
#
# ### Forward Kinematics ###
# Pose:            (-0.148739, 0.918744, 1.2353, 0.749859, 0.12279, 1.9692)
# Custom Solver:   (-0.148738, 0.918744, 1.2353, 0.749859, 0.12279, 1.9692)
#
# ### Errors ###
# Custom Solver:   [-6.723186252435474e-06, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  3  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.69073, 1.103247, -1.250676, -1.238401, -0.635874, -0.877345]
#
# ### Forward Kinematics ###
# Pose:            (-0.437605, -0.142628, 0.773473, -0.877345, 1.874275, 0.5433)
# Custom Solver:   (-0.437605, -0.142628, 0.773473, 2.264248, 1.267318, -2.598293)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  4  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.771877, -0.886726, 1.722349, 1.29781, 0.495306, -0.447094]
#
# ### Forward Kinematics ###
# Pose:            (0.09348, 0.499174, 1.671298, -0.447094, -1.793116, 1.6075)
# Custom Solver:   (0.09348, 0.499174, 1.671298, 2.694499, -1.348477, -1.534093)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  5  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.919087, -0.509006, -0.464681, 0.54039, 0.91588, -0.231775]
#
# ### Forward Kinematics ###
# Pose:            (0.238741, 0.254588, 1.493843, -0.231775, -1.45627, -0.0546)
# Custom Solver:   (0.238741, 0.254588, 1.493843, -0.231775, -1.45627, -0.0546)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  6  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.283864, 0.171493, 1.443071, 0.979343, 0.757913, 0.910853]
#
# ### Forward Kinematics ###
# Pose:            (0.269402, 0.529721, 1.594078, 0.910853, -1.737256, 1.3307)
# Custom Solver:   (0.269402, 0.529721, 1.594078, -2.23074, -1.404337, -1.810893)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  7  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.259945, 1.704179, 2.972361, -1.524965, 0.925275, -1.002714]
#
# ### Forward Kinematics ###
# Pose:            (-0.050847, -0.026267, 0.957833, -1.002714, 0.59969, -1.3467)
# Custom Solver:   (-0.050847, -0.026267, 0.957833, -1.002714, 0.59969, -1.3467)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  8  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   []
#
# ### Forward Kinematics ###
# Pose:            (0.281014, -0.18202, 1.405949, -0.709019, -0.936484, -1.7912)
#
# ### Errors ###
# Custom Solver:   ['no', 'no', 'no']
#
#
# -------------------------------
# ---------- TEST  9  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.675726, -0.237693, -2.684733, -1.371791, -1.284726, 0.620646]
#
# ### Forward Kinematics ###
# Pose:            (0.37203, 0.757159, 1.018526, 0.620646, 2.656517, -2.2467)
# Custom Solver:   (0.37203, 0.757159, 1.018526, -2.520947, 0.485076, 0.894893)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  10  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.868524, 1.315467, -0.531144, 1.044751, 0.615917, -0.126281]
#
# ### Forward Kinematics ###
# Pose:            (0.406447, 0.249833, 1.611298, -0.126281, -1.660668, -0.0842)
# Custom Solver:   (0.406447, 0.249833, 1.611298, 3.015312, -1.480925, 3.057393)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  11  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.892555, 0.638963, -2.363408, 0.648723, 0.321757, -0.498745]
#
# ### Forward Kinematics ###
# Pose:            (-0.080874, 0.055557, 1.431689, -0.498745, -0.97048, -2.617)
# Custom Solver:   (-0.080874, 0.055557, 1.431689, -0.498745, -0.97048, -2.617)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  12  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.690323, 1.254421, -1.050197, 0.632231, -0.540691, 1.296135]
#
# ### Forward Kinematics ###
# Pose:            (0.654488, -0.005291, 1.120293, 1.296135, -0.09154, -0.4861)
# Custom Solver:   (0.654488, -0.00529, 1.120293, 1.296135, -0.09154, -0.4861)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.00018900018900005016, 0.0]
#
#
# -------------------------------
# ---------- TEST  13  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.527444, 0.630975, -0.77262, 1.234852, -0.995835, -1.135413]
#
# ### Forward Kinematics ###
# Pose:            (0.509763, 0.435993, 1.319226, -1.135413, -0.239017, 0.3858)
# Custom Solver:   (0.509763, 0.435993, 1.319226, -1.135413, -0.239017, 0.3858)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  14  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.874094, 0.316528, -0.369034, -1.467574, 0.198332, 1.256565]
#
# ### Forward Kinematics ###
# Pose:            (0.274947, 0.382559, 0.805614, 1.256565, 1.269242, -0.9266)
# Custom Solver:   (0.274947, 0.382559, 0.805614, 1.256565, 1.269242, -0.9266)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  15  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.203807, -0.101973, -1.371333, -0.888479, -0.792452, 0.086602]
#
# ### Forward Kinematics ###
# Pose:            (0.046458, 0.553538, 0.685576, 0.086602, 1.680931, -1.2695)
# Custom Solver:   (0.046458, 0.553538, 0.685576, -3.054991, 1.460662, 1.872093)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  16  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.666398, 0.648558, -2.37596, 0.481957, -0.830556, 0.172862]
#
# ### Forward Kinematics ###
# Pose:            (-0.149217, -0.054131, 0.921587, 0.172862, 0.348599, -2.3938)
# Custom Solver:   (-0.149217, -0.054131, 0.921587, 0.172862, 0.348599, -2.3938)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  17  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.543709, -0.875152, 2.613561, -0.180922, 0.803269, 0.72991]
#
# ### Forward Kinematics ###
# Pose:            (0.566802, 0.470868, 1.23282, 0.72991, -0.622347, 1.1947)
# Custom Solver:   (0.566802, 0.470868, 1.23282, 0.72991, -0.622347, 1.1947)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  18  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.922914, 0.848229, 0.823557, 1.272894, -1.659672, -0.465473]
#
# ### Forward Kinematics ###
# Pose:            (-0.667258, 0.350661, 1.084901, -0.465473, 0.386778, 2.5947)
# Custom Solver:   (-0.667258, 0.350661, 1.084901, -0.465473, 0.386778, 2.5947)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  19  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.294812, 0.607024, -1.819436, 1.4291, -0.549956, -0.850764]
#
# ### Forward Kinematics ###
# Pose:            (0.286017, -0.1772, 1.593626, -0.850764, -0.879144, -0.9176)
# Custom Solver:   (0.286017, -0.1772, 1.593626, -0.850764, -0.879144, -0.9176)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  20  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.276699, 0.656631, -2.875829, -1.207794, 0.271179, -0.684129]
#
# ### Forward Kinematics ###
# Pose:            (-0.041157, 0.245739, 0.796126, -0.684129, 0.936615, -1.9425)
# Custom Solver:   (-0.041157, 0.245739, 0.796126, -0.684129, 0.936615, -1.9425)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  21  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.742913, 0.810874, -2.680861, -1.169415, 0.405132, -1.178461]
#
# ### Forward Kinematics ###
# Pose:            (0.17913, 0.271743, 0.829135, -1.178461, 0.764283, -2.6129)
# Custom Solver:   (0.17913, 0.271743, 0.829135, -1.178461, 0.764283, -2.6129)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  22  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.846209, 1.395131, 2.258445, 0.452887, -1.297303, -0.210158]
#
# ### Forward Kinematics ###
# Pose:            (-0.180891, -0.44462, 0.763741, -0.210158, 0.844416, -1.7834)
# Custom Solver:   (-0.180891, -0.44462, 0.763741, -0.210158, 0.844416, -1.7834)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  23  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.039376, 0.934842, 1.657034, 1.534806, 0.192776, 0.234533]
#
# ### Forward Kinematics ###
# Pose:            (-0.183327, 0.378351, 1.734404, 0.234533, -1.727582, 2.5525)
# Custom Solver:   (-0.183327, 0.378351, 1.734404, -2.90706, -1.414011, -0.589093)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  24  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.822615, 0.200299, -2.358614, 0.094145, 0.489738, -0.612915]
#
# ### Forward Kinematics ###
# Pose:            (-0.007282, -0.229869, 1.232883, -0.612915, -0.583883, -1.3357)
# Custom Solver:   (-0.007282, -0.229869, 1.232883, -0.612915, -0.583883, -1.3357)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  25  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.403631, 1.641327, -0.692796, -0.77357, -0.528438, -0.299114]
#
# ### Forward Kinematics ###
# Pose:            (-0.039495, 0.152117, 0.668272, -0.299114, 1.302008, 0.5449)
# Custom Solver:   (-0.039495, 0.152117, 0.668272, -0.299114, 1.302008, 0.5449)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  26  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.629302, 0.743887, -2.422885, -1.3e-05, 0.413646, 0.25297]
#
# ### Forward Kinematics ###
# Pose:            (-0.085965, -0.01597, 1.163642, 0.25297, -0.413633, -2.3083)
# Custom Solver:   (-0.085965, -0.01597, 1.163642, 0.25297, -0.413633, -2.3083)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  27  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.759343, 1.445307, -0.73955, -0.661177, 1.049873, -0.738148]
#
# ### Forward Kinematics ###
# Pose:            (-0.063877, 0.239247, 1.169758, -0.738148, -0.388696, 1.4651)
# Custom Solver:   (-0.063877, 0.239247, 1.169758, -0.738148, -0.388696, 1.4651)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  28  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.258084, 1.448121, 2.631649, 1.08541, -0.917517, -1.37975]
#
# ### Forward Kinematics ###
# Pose:            (-0.507606, -0.210459, 1.253219, -1.37975, -0.167893, -2.4615)
# Custom Solver:   (-0.507606, -0.210459, 1.253219, -1.37975, -0.167893, -2.4615)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  29  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.008671, 0.875626, -2.597897, -1.508992, -1.184986, -0.33476]
#
# ### Forward Kinematics ###
# Pose:            (0.085218, 0.870683, 1.065259, -0.33476, 2.693978, -1.7136)
# Custom Solver:   (0.085218, 0.870683, 1.065259, 2.806833, 0.447615, 1.427993)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  30  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.572095, 0.59307, -2.803175, -0.084505, -1.645177, 0.362977]
#
# ### Forward Kinematics ###
# Pose:            (0.278253, 0.335378, 0.640242, 0.362977, 1.729682, -2.7822)
# Custom Solver:   (0.278253, 0.335378, 0.640242, -2.778616, 1.411911, 0.359393)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  31  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.135453, 1.164439, 0.432614, -1.297454, -1.290767, -1.420239]
#
# ### Forward Kinematics ###
# Pose:            (-0.066491, -0.347562, 0.976712, -1.420239, 2.588221, 1.4616)
# Custom Solver:   (-0.066491, -0.347562, 0.976712, 1.721354, 0.553372, -1.679993)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  32  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.692875, -0.318385, 0.75541, 0.701611, 1.466367, -0.69815]
#
# ### Forward Kinematics ###
# Pose:            (0.010358, 0.300364, 1.481428, -0.69815, -2.167978, 1.1299)
# Custom Solver:   (0.010358, 0.300364, 1.481428, 2.443443, -0.973615, -2.011693)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  33  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.686639, -0.917496, -0.516765, -1.158287, 1.362127, -1.086298]
#
# ### Forward Kinematics ###
# Pose:            (0.349838, -0.078169, 1.175883, -1.086298, -0.20384, -2.1209)
# Custom Solver:   (0.349838, -0.078169, 1.175883, -1.086298, -0.20384, -2.1209)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  34  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.910663, 0.940363, -1.302801, -1.481101, 1.400619, 0.955114]
#
# ### Forward Kinematics ###
# Pose:            (0.297448, 0.140424, 1.134889, 0.955114, 0.080482, -1.2731)
# Custom Solver:   (0.297448, 0.140424, 1.134889, 0.955114, 0.080482, -1.2731)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  35  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.229349, -1.032276, -2.265261, -1.533006, 0.788199, -0.748759]
#
# ### Forward Kinematics ###
# Pose:            (0.369107, 0.193, 0.917506, -0.748759, 0.744807, 2.7563)
# Custom Solver:   (0.369107, 0.193, 0.917506, -0.748759, 0.744807, 2.7563)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  36  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.192568, -0.053289, 2.011622, 1.455692, -0.740245, -1.472569]
#
# ### Forward Kinematics ###
# Pose:            (-0.207939, 0.814015, 1.550724, -1.472569, -0.715447, 2.1509)
# Custom Solver:   (-0.20794, 0.814015, 1.550724, -1.472569, -0.715447, 2.1509)
#
# ### Errors ###
# Custom Solver:   [-4.809102669537701e-06, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  37  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.742493, 0.776652, -0.88896, -1.068845, -0.172328, 1.064857]
#
# ### Forward Kinematics ###
# Pose:            (0.177126, 0.371625, 0.721127, 1.064857, 1.241173, -0.8548)
# Custom Solver:   (0.177126, 0.371625, 0.721127, 1.064857, 1.241173, -0.8548)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  38  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.978643, 0.611024, 0.756219, -0.468601, 1.185102, 0.403852]
#
# ### Forward Kinematics ###
# Pose:            (0.58512, 0.366633, 1.270804, 0.403852, -0.716501, 0.3886)
# Custom Solver:   (0.58512, 0.366633, 1.270804, 0.403852, -0.716501, 0.3886)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  39  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.950927, 1.131865, -0.462238, -1.486308, -1.09068, 0.997972]
#
# ### Forward Kinematics ###
# Pose:            (-0.352052, 0.446033, 1.016892, 0.997972, 2.576988, -0.2813)
# Custom Solver:   (-0.352052, 0.446033, 1.016892, -2.143621, 0.564605, 2.860293)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  40  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.302104, -0.450613, 2.408409, -1.243829, 0.056416, 0.965154]
#
# ### Forward Kinematics ###
# Pose:            (0.219517, 0.250637, 0.762527, 0.965154, 1.187413, 2.2599)
# Custom Solver:   (0.219517, 0.250637, 0.762527, 0.965154, 1.187413, 2.2599)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  41  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.440974, -0.512544, 1.81057, -0.153049, 1.373201, 0.330203]
#
# ### Forward Kinematics ###
# Pose:            (0.092954, 0.510218, 1.391745, 0.330203, -1.220152, 1.739)
# Custom Solver:   (0.092954, 0.510218, 1.391745, 0.330203, -1.220152, 1.739)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  42  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.338518, -0.034863, -0.321854, 1.192452, -1.474966, 1.000513]
#
# ### Forward Kinematics ###
# Pose:            (0.686043, 0.306416, 1.10262, 1.000513, 0.282514, -0.0182)
# Custom Solver:   (0.686043, 0.306417, 1.10262, 1.000513, 0.282514, -0.0182)
#
# ### Errors ###
# Custom Solver:   [0.0, 3.2635371520196218e-06, 0.0]
#
#
# -------------------------------
# ---------- TEST  43  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.698401, 0.452474, 2.728227, -0.998631, 1.479071, -1.499883]
#
# ### Forward Kinematics ###
# Pose:            (0.139372, 0.418017, 1.252451, -1.499883, -0.48044, 2.4823)
# Custom Solver:   (0.139372, 0.418017, 1.252451, -1.499883, -0.48044, 2.4823)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  44  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.927137, -0.922995, 2.036658, -0.832616, 0.694665, -0.037555]
#
# ### Forward Kinematics ###
# Pose:            (-0.049055, 0.50637, 0.982373, -0.037555, 0.137951, 2.0408)
# Custom Solver:   (-0.049055, 0.50637, 0.982373, -0.037555, 0.137951, 2.0408)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  45  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.936235, 1.020787, 1.927447, -0.519811, 1.446999, 0.205215]
#
# ### Forward Kinematics ###
# Pose:            (0.159212, 0.460755, 1.336658, 0.205215, -0.927188, 2.012)
# Custom Solver:   (0.159212, 0.460755, 1.336658, 0.205215, -0.927188, 2.012)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  46  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.952312, 0.014922, 1.37689, 1.418622, 0.105397, 0.909589]
#
# ### Forward Kinematics ###
# Pose:            (0.711308, 0.327508, 1.702534, 0.909589, -1.524019, 0.4395)
# Custom Solver:   (0.711308, 0.327508, 1.702534, 0.909589, -1.524019, 0.4395)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  47  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.213557, -0.181398, 0.958841, 1.3995, -1.031027, -0.28888]
#
# ### Forward Kinematics ###
# Pose:            (0.480385, 0.867836, 1.412036, -0.28888, -0.368473, 0.991)
# Custom Solver:   (0.480385, 0.867836, 1.412036, -0.28888, -0.368473, 0.991)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  48  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.954035, 0.948097, 0.160538, 0.165808, -1.003164, 1.45549]
#
# ### Forward Kinematics ###
# Pose:            (0.601889, 0.335634, 0.727407, 1.45549, 0.837356, 0.1546)
# Custom Solver:   (0.601889, 0.335634, 0.727407, 1.45549, 0.837356, 0.1546)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  49  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.659857, -0.174219, -1.470238, 1.417877, 0.766352, -0.54896]
#
# ### Forward Kinematics ###
# Pose:            (0.01714, 0.240318, 1.651015, -0.54896, -2.184229, -0.9846)
# Custom Solver:   (0.01714, 0.240318, 1.651015, 2.592633, -0.957364, 2.156993)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  50  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.692747, 0.872094, 0.312353, -1.40179, -0.612028, -0.444481]
#
# ### Forward Kinematics ###
# Pose:            (-0.183294, 0.096286, 0.835163, -0.444481, 2.013818, 0.4917)
# Custom Solver:   (-0.183294, 0.096286, 0.835163, 2.697112, 1.127775, -2.649893)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  51  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.715668, 0.916881, -1.770213, 0.480962, 1.630378, 1.461664]
#
# ### Forward Kinematics ###
# Pose:            (0.19999, 0.308468, 1.450475, 1.461664, -2.11134, -1.569)
# Custom Solver:   (0.19999, 0.308468, 1.450475, -1.679929, -1.030253, 1.572593)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  52  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.992443, 0.731215, 1.862828, 0.15707, 1.13333, 0.523598]
#
# ### Forward Kinematics ###
# Pose:            (-0.368167, -0.069282, 1.42142, 0.523598, -1.2904, -2.6967)
# Custom Solver:   (-0.368167, -0.069282, 1.42142, 0.523598, -1.2904, -2.6967)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  53  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.991231, 1.15787, -0.752339, -0.504968, -1.454739, 0.726791]
#
# ### Forward Kinematics ###
# Pose:            (0.020098, 0.414946, 0.678814, 0.726791, 1.959707, -0.5857)
# Custom Solver:   (0.020098, 0.414946, 0.678814, -2.414802, 1.181886, 2.555893)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  54  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.365817, 0.648413, -0.284131, 1.194268, -0.098282, -0.500338]
#
# ### Forward Kinematics ###
# Pose:            (0.285937, 0.537668, 1.587449, -0.500338, -1.095986, 0.7301)
# Custom Solver:   (0.285937, 0.537668, 1.587449, -0.500338, -1.095986, 0.7301)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  55  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.82769, 0.21694, -0.80545, -0.401478, 0.529024, -1.381764]
#
# ### Forward Kinematics ###
# Pose:            (0.429063, -0.098164, 1.047509, -1.381764, -0.127546, -1.4162)
# Custom Solver:   (0.429063, -0.098164, 1.047509, -1.381764, -0.127546, -1.4162)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  56  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.420419, -0.145666, -2.501453, -1.513333, 1.646752, -0.709705]
#
# ### Forward Kinematics ###
# Pose:            (-0.040549, 0.19239, 1.22831, -0.709705, -0.133419, -2.2267)
# Custom Solver:   (-0.040549, 0.19239, 1.22831, -0.709705, -0.133419, -2.2267)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  57  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.619418, 1.51139, 1.115528, -0.101616, -0.452875, 1.013049]
#
# ### Forward Kinematics ###
# Pose:            (-0.082708, 0.555983, 0.789688, 1.013049, 0.554491, 2.0075)
# Custom Solver:   (-0.082708, 0.555983, 0.789688, 1.013049, 0.554491, 2.0075)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  58  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.465918, 0.943139, -0.563057, 0.223775, -1.310314, -0.507903]
#
# ### Forward Kinematics ###
# Pose:            (0.076667, 0.345631, 0.683686, -0.507903, 1.086539, 0.846)
# Custom Solver:   (0.076667, 0.345631, 0.683686, -0.507903, 1.086539, 0.846)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  59  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.031662, -0.064247, 2.324085, -0.686988, 0.696965, -0.809313]
#
# ### Forward Kinematics ###
# Pose:            (-0.025544, 0.551417, 1.022423, -0.809313, -0.009977, 2.2915)
# Custom Solver:   (-0.025548, 0.551306, 1.022423, -0.809313, -0.009977, 2.2915)
#
# ### Errors ###
# Custom Solver:   [-0.0001565925461948219, 0.00020129956094948695, 0.0]
#
#
# -------------------------------
# ---------- TEST  60  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.382991, -0.179973, 1.521682, -0.077491, 1.575029, -0.856909]
#
# ### Forward Kinematics ###
# Pose:            (0.057576, 0.423775, 1.426541, -0.856909, -1.497538, 1.7247)
# Custom Solver:   (0.057576, 0.423775, 1.426541, -0.856909, -1.497538, 1.7247)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  61  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.473434, -0.286214, 0.723681, -0.788812, -1.635285, -0.359089]
#
# ### Forward Kinematics ###
# Pose:            (-0.214159, -0.044623, 0.827579, -0.359089, 2.424097, 0.9109)
# Custom Solver:   (-0.214159, -0.044623, 0.827579, 2.782504, 0.717496, -2.230693)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  62  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.909798, -0.921033, -0.691269, 1.328176, 0.563032, 0.024365]
#
# ### Forward Kinematics ###
# Pose:            (0.331343, -0.073603, 1.671772, 0.024365, -1.891208, -2.5221)
# Custom Solver:   (0.331343, -0.073603, 1.671772, -3.117228, -1.250385, 0.619493)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  63  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.936265, 0.660833, 0.201102, -0.550071, -0.801913, -1.181701]
#
# ### Forward Kinematics ###
# Pose:            (-0.142861, 0.04232, 0.641523, -1.181701, 1.351984, 1.7982)
# Custom Solver:   (-0.142861, 0.04232, 0.641523, -1.181701, 1.351984, 1.7982)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  64  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.523685, 1.697903, -0.743718, -1.130361, 0.344914, 1.315638]
#
# ### Forward Kinematics ###
# Pose:            (0.081447, 0.212647, 0.815672, 1.315638, 0.785447, 0.4305)
# Custom Solver:   (0.081447, 0.212647, 0.815672, 1.315638, 0.785447, 0.4305)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  65  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.116247, -0.038027, -0.01432, 1.445606, 1.057296, -1.023174]
#
# ### Forward Kinematics ###
# Pose:            (0.084982, 0.330066, 1.577195, -1.023174, -2.502902, 0.0639)
# Custom Solver:   (0.084982, 0.330066, 1.577195, 2.118419, -0.638691, -3.077693)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  66  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.850429, -0.631969, 1.433098, 0.505523, 0.884342, -0.448629]
#
# ### Forward Kinematics ###
# Pose:            (0.743401, 0.0858, 1.481553, -0.448629, -1.389865, -0.0493)
# Custom Solver:   (0.743401, 0.0858, 1.481553, -0.448629, -1.389865, -0.0493)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  67  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.118105, 0.754871, -2.537476, -0.989176, -0.754973, -0.207642]
#
# ### Forward Kinematics ###
# Pose:            (0.011094, 0.534229, 0.70793, -0.207642, 1.744149, -1.6645)
# Custom Solver:   (0.011094, 0.534229, 0.70793, 2.933951, 1.397444, 1.477093)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  68  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.576896, 0.906961, -0.060757, -1.316077, 1.589216, -0.18664]
#
# ### Forward Kinematics ###
# Pose:            (-0.091218, 0.287744, 1.237357, -0.18664, -0.273139, 1.4231)
# Custom Solver:   (-0.091218, 0.287744, 1.237357, -0.18664, -0.273139, 1.4231)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  69  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.11974, 1.466757, 0.668603, -1.350269, 0.146071, 0.489728]
#
# ### Forward Kinematics ###
# Pose:            (0.010117, 0.026699, 0.784378, 0.489728, 1.204198, 2.2551)
# Custom Solver:   (0.010117, 0.026699, 0.784378, 0.489728, 1.204198, 2.2551)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  70  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.38322, 0.985497, -0.637117, 0.968106, -1.122501, -1.408775]
#
# ### Forward Kinematics ###
# Pose:            (0.376668, 0.576478, 1.096172, -1.408775, 0.154395, 0.7316)
# Custom Solver:   (0.376668, 0.576478, 1.096172, -1.408775, 0.154395, 0.7316)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  71  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.820256, 0.853762, 1.013593, -0.686153, 0.524169, 0.398709]
#
# ### Forward Kinematics ###
# Pose:            (0.38348, 0.536123, 0.954272, 0.398709, 0.161984, 1.0471)
# Custom Solver:   (0.38348, 0.536123, 0.954272, 0.398709, 0.161984, 1.0471)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  72  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.556126, 1.441504, -1.167429, 0.324577, -1.613845, 1.098438]
#
# ### Forward Kinematics ###
# Pose:            (0.049246, 0.174769, 0.672437, 1.098438, 1.289268, 0.8302)
# Custom Solver:   (0.049246, 0.174769, 0.672437, 1.098438, 1.289268, 0.8302)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  73  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.872257, -0.847243, 2.118486, 0.145572, -0.249531, -1.487415]
#
# ### Forward Kinematics ###
# Pose:            (-0.202535, 0.702358, 0.970012, -1.487415, 0.103959, 2.1435)
# Custom Solver:   (-0.202535, 0.702358, 0.970012, -1.487415, 0.103959, 2.1435)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  74  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.343928, 0.33663, -2.301503, 0.209278, 1.224487, 0.7972]
#
# ### Forward Kinematics ###
# Pose:            (0.071135, 0.180287, 1.443504, 0.7972, -1.433765, -2.3088)
# Custom Solver:   (0.071135, 0.180287, 1.443504, 0.7972, -1.433765, -2.3088)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  75  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.984806, 0.919069, -1.110375, 0.804362, -0.971391, -0.258529]
#
# ### Forward Kinematics ###
# Pose:            (0.287255, 0.433084, 1.053496, -0.258529, 0.167029, 0.7935)
# Custom Solver:   (0.287255, 0.433084, 1.053496, -0.258529, 0.167029, 0.7935)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  76  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.436924, -1.10651, -0.053066, 1.234206, -0.269738, -0.692388]
#
# ### Forward Kinematics ###
# Pose:            (0.412631, -0.393764, 1.566719, -0.692388, -0.964468, -1.5965)
# Custom Solver:   (0.412631, -0.393764, 1.566719, -0.692388, -0.964468, -1.5965)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  77  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.253828, -0.320016, -2.170311, 0.686359, -1.62213, -1.327357]
#
# ### Forward Kinematics ###
# Pose:            (-0.110504, 0.004414, 0.786216, -1.327357, 0.935771, -2.2365)
# Custom Solver:   (-0.110504, 0.004414, 0.786216, -1.327357, 0.935771, -2.2365)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  78  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.164221, 0.066272, -1.586151, -1.38229, 0.510595, -0.184591]
#
# ### Forward Kinematics ###
# Pose:            (0.20298, 0.333781, 0.849354, -0.184591, 0.871695, -1.6841)
# Custom Solver:   (0.20298, 0.333781, 0.849354, -0.184591, 0.871695, -1.6841)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  79  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.704193, 0.673658, -2.747265, -1.438106, -1.472175, 1.291465]
#
# ### Forward Kinematics ###
# Pose:            (0.842171, 0.53157, 1.131977, 1.291465, 2.910281, -2.7778)
# Custom Solver:   (0.842171, 0.53157, 1.131977, -1.850128, 0.231312, 0.363793)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  80  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.13831, -0.999573, -2.643922, -1.176223, -1.432527, -0.510111]
#
# ### Forward Kinematics ###
# Pose:            (0.837395, 0.057223, 0.957984, -0.510111, 2.60875, 2.778)
# Custom Solver:   (0.837395, 0.057223, 0.957984, 2.631482, 0.532843, -0.363593)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  81  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.828137, 0.600393, -0.700831, 0.041865, -1.14886, -0.655697]
#
# ### Forward Kinematics ###
# Pose:            (0.025354, 0.258502, 0.663776, -0.655697, 1.106995, 0.7277)
# Custom Solver:   (0.025354, 0.258502, 0.663776, -0.655697, 1.106995, 0.7277)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  82  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.8724, 1.472396, 0.077704, -0.395126, -0.546442, 0.316755]
#
# ### Forward Kinematics ###
# Pose:            (0.266563, 0.35873, 0.686688, 0.316755, 0.941568, 0.6777)
# Custom Solver:   (0.266563, 0.35873, 0.686688, 0.316755, 0.941568, 0.6777)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  83  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.502098, 0.493548, -1.091646, 0.844344, 0.880862, -0.502233]
#
# ### Forward Kinematics ###
# Pose:            (0.122308, 0.203715, 1.562931, -0.502233, -1.725206, -0.096)
# Custom Solver:   (0.122308, 0.203715, 1.562931, 2.63936, -1.416387, 3.045593)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  84  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.61435, -0.525437, 1.302587, -0.594097, 1.254844, 0.915183]
#
# ### Forward Kinematics ###
# Pose:            (0.668976, 0.228709, 1.261718, 0.915183, -0.660747, 0.1628)
# Custom Solver:   (0.668976, 0.228709, 1.261718, 0.915183, -0.660747, 0.1628)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  85  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.850208, -0.468583, 2.81056, -0.203671, 0.270412, 0.540792]
#
# ### Forward Kinematics ###
# Pose:            (-0.418252, 0.256855, 1.019763, 0.540792, -0.066741, -3.091)
# Custom Solver:   (-0.418252, 0.256855, 1.019763, 0.540792, -0.066741, -3.091)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  86  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.856098, 0.683533, 1.899666, -1.176035, -0.060871, 1.44398]
#
# ### Forward Kinematics ###
# Pose:            (0.307708, 0.182643, 0.7428, 1.44398, 1.236906, 1.7271)
# Custom Solver:   (0.307708, 0.182643, 0.7428, 1.44398, 1.236906, 1.7271)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  87  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.63488, 0.31614, -2.14056, -0.172157, -0.898515, 0.222471]
#
# ### Forward Kinematics ###
# Pose:            (0.162598, 0.187435, 0.660089, 0.222471, 1.070672, -2.4593)
# Custom Solver:   (0.162598, 0.187435, 0.660089, 0.222471, 1.070672, -2.4593)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  88  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.404821, 0.799317, -1.110237, -1.139137, 0.449436, -0.512856]
#
# ### Forward Kinematics ###
# Pose:            (0.001349, 0.196653, 0.843576, -0.512856, 0.689701, 0.0939)
# Custom Solver:   (0.001349, 0.196653, 0.843576, -0.512856, 0.689701, 0.0939)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  89  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.13079, 0.958898, 0.124292, -1.374651, -0.788531, -0.473335]
#
# ### Forward Kinematics ###
# Pose:            (-0.258827, -0.129606, 0.862762, -0.473335, 2.163182, 0.9524)
# Custom Solver:   (-0.258827, -0.129606, 0.862762, 2.668258, 0.978411, -2.189193)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  90  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.871521, -0.659257, -1.491063, 1.310197, 1.515894, -1.088554]
#
# ### Forward Kinematics ###
# Pose:            (-0.00913, 0.394934, 1.433256, -1.088554, -2.826091, -1.2788)
# Custom Solver:   (-0.00913, 0.394934, 1.433256, 2.053039, -0.315502, 1.862793)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  91  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.999665, -0.431845, 1.02038, 0.693953, 1.044157, -0.935994]
#
# ### Forward Kinematics ###
# Pose:            (-0.058069, 0.417218, 1.530039, -0.935994, -1.73811, 1.5882)
# Custom Solver:   (-0.058069, 0.417218, 1.530039, 2.205599, -1.403483, -1.553393)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  92  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.918256, -0.411508, -2.501347, 0.16465, -1.037472, 0.199959]
#
# ### Forward Kinematics ###
# Pose:            (-0.174348, -0.041994, 0.718893, 0.199959, 0.872822, -1.9946)
# Custom Solver:   (-0.174348, -0.041994, 0.718893, 0.199959, 0.872822, -1.9946)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  93  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.632096, 1.456945, 1.358644, -0.543147, -0.536552, 1.21745]
#
# ### Forward Kinematics ###
# Pose:            (-0.172089, -0.030691, 0.670064, 1.21745, 1.079699, -2.8355)
# Custom Solver:   (-0.172089, -0.030691, 0.670064, 1.21745, 1.079699, -2.8355)
#
# ### Errors ###
# Custom Solver:   [-0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  94  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.907008, 1.150613, 1.733095, -0.346234, 1.316671, 0.269474]
#
# ### Forward Kinematics ###
# Pose:            (0.11813, 0.488822, 1.33926, 0.269474, -0.970437, 1.9767)
# Custom Solver:   (0.11813, 0.488822, 1.33926, 0.269474, -0.970437, 1.9767)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  95  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.863692, -0.184874, 1.191882, -1.548241, -1.207465, -1.11866]
#
# ### Forward Kinematics ###
# Pose:            (0.122166, -0.35822, 1.098347, -1.11866, 2.755706, 1.8707)
# Custom Solver:   (0.122166, -0.35822, 1.098347, 2.022933, 0.385887, -1.270893)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  96  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.825775, 0.35942, 2.273456, 1.010877, -1.31401, 0.416671]
#
# ### Forward Kinematics ###
# Pose:            (0.203518, 0.869796, 1.049735, 0.416671, 0.303133, 1.8071)
# Custom Solver:   (0.203517, 0.869796, 1.049735, 0.416671, 0.303133, 1.8071)
#
# ### Errors ###
# Custom Solver:   [4.913570298455174e-06, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  97  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.595864, 0.108982, 2.477582, -1.302597, -0.511857, 1.317176]
#
# ### Forward Kinematics ###
# Pose:            (0.474131, -0.034216, 0.779179, 1.317176, 1.814454, 1.9907)
# Custom Solver:   (0.474131, -0.034216, 0.779179, -1.824417, 1.327139, -1.150893)
#
# ### Errors ###
# Custom Solver:   [0.0, -0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  98  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.19966, 0.211675, -2.135715, -0.588907, -0.798057, -0.897512]
#
# ### Forward Kinematics ###
# Pose:            (0.209336, 0.373514, 0.643142, -0.897512, 1.386964, -2.1237)
# Custom Solver:   (0.209336, 0.373514, 0.643142, -0.897512, 1.386964, -2.1237)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  99  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [0.703081, -0.180568, 2.780072, 0.762822, -0.03815, 1.022183]
#
# ### Forward Kinematics ###
# Pose:            (-0.553504, 0.19101, 1.384158, 1.022183, -0.724672, -2.9806)
# Custom Solver:   (-0.553504, 0.19101, 1.384158, 1.022183, -0.724672, -2.9806)
#
# ### Errors ###
# Custom Solver:   [-0.0, 0.0, 0.0]
#
#
# -------------------------------
# ---------- TEST  100  ----------
# -------------------------------
# ### Inverse Kinematics ###
# Custom Solver:   [-0.176578, 0.143565, 2.065613, -0.549084, -0.870371, -0.578718]
#
# ### Forward Kinematics ###
# Pose:            (0.213721, 0.285855, 0.638734, -0.578718, 1.419455, 2.0326)
# Custom Solver:   (0.213721, 0.285855, 0.638734, -0.578718, 1.419455, 2.0326)
#
# ### Errors ###
# Custom Solver:   [0.0, 0.0, 0.0]
